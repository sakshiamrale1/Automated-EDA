# %% [markdown]
# # Automated EDA

# %% [markdown]
# # Extraction Of Data:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel(r"C:\Users\Owner\Desktop\DS\PowerBI\Global Superstore Sales Data.xlsx")

# %%
df = data.copy()

# %%
df.head()
# Out:
#   Order Date  Ship Date     Ship Mode   Customer ID     Customer Name  \
# 0 2014-11-11 2014-11-13   First Class  AB-100151402     Aaron Bergman
# 1 2014-02-05 2014-02-07  Second Class     JR-162107     Justin Ritter
# 2 2014-10-17 2014-10-18   First Class     CR-127307      Craig Reiter
# 3 2014-01-28 2014-01-30   First Class    KM-1637548  Katherine Murray
# 4 2014-11-05 2014-11-06      Same Day    RH-9495111       Rick Hansen
#
#        Segment           City            State        Country          Region  \
# 0     Consumer  Oklahoma City         Oklahoma  United States      Central US
# 1    Corporate     Wollongong  New South Wales      Australia         Oceania
# 2     Consumer       Brisbane       Queensland      Australia         Oceania
# 3  Home Office         Berlin           Berlin        Germany  Western Europe
# 4     Consumer          Dakar            Dakar        Senegal  Western Africa
#
#    ...   Product ID    Category Sub-Category  \
# ...

# %% [markdown]
# ## Interpretetion of Data:

# %% [markdown]
# Data Size:

# %%
print("No. of columns in the data are :",df.shape[1],"\n No. of rows in data are :",df.shape[0])
# Out:
# No. of columns in the data are : 21
#  No. of rows in data are : 51290

# %%
print("Following columns are presents in Dataset:")
for i in df.columns:
    print(i)
# Out:
# Following columns are presents in Dataset:
# Order Date
# Ship Date
# Ship Mode
# Customer ID
# Customer Name
# Segment
# City
# State
# Country
# Region
# Market
# Product ID
# Category
# Sub-Category
# Product Name
# Sales
# Quantity
# Discount
# Profit
# Shipping Cost
# Order Priority

# %% [markdown]
# Columns and their Datatypes:

# %%
for i in df.columns:
    print("Data type of :",i," is :",df.dtypes[i])
# Out:
# Data type of : Order Date  is : datetime64[ns]
# Data type of : Ship Date  is : datetime64[ns]
# Data type of : Ship Mode  is : object
# Data type of : Customer ID  is : object
# Data type of : Customer Name  is : object
# Data type of : Segment  is : object
# Data type of : City  is : object
# Data type of : State  is : object
# Data type of : Country  is : object
# Data type of : Region  is : object
# Data type of : Market  is : object
# Data type of : Product ID  is : object
# Data type of : Category  is : object
# Data type of : Sub-Category  is : object
# Data type of : Product Name  is : object
# Data type of : Sales  is : float64
# Data type of : Quantity  is : int64
# Data type of : Discount  is : float64
# Data type of : Profit  is : float64
# Data type of : Shipping Cost  is : float64
# Data type of : Order Priority  is : object

# %% [markdown]
# Finding Null Values:

# %%
df.isnull().sum()
# Out:
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Region            0
# Market            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# dtype: int64

# %% [markdown]
# ## Analysis of Data:

# %% [markdown]
# ### EDA on Numerical DATA:

# %%
num_df = df.select_dtypes(include=np.number)

# %%
Total_List = []
for i in range(len(num_df.columns)):
    Total_List.append(num_df.iloc[:,i].sum())
    

x = num_df.columns
y = Total_List

print(x)
print()
plt.bar(x,y)
plt.show()
# Out:
# Index(['Sales', 'Quantity', 'Discount', 'Profit', 'Shipping Cost'], dtype='object')

# %% [markdown]
# ## EDA on Non-Numerical DATA:

# %%
non_num_df = df.select_dtypes(exclude=np.number)
non_num_df.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name',
#        'Segment', 'City', 'State', 'Country', 'Region', 'Market', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Order Priority'],
#       dtype='object')

# %% [markdown]
# Unique Values of Each Categorical Column:

# %%
for i in non_num_df.columns:
    print("Unique Values for column ",i," are:")
    print(df[i].unique())
    print()
    print()
# Out:
# Unique Values for column  Order Date  are:
# ['2014-11-11T00:00:00.000000000' '2014-02-05T00:00:00.000000000'
#  '2014-10-17T00:00:00.000000000' ... '2012-02-13T00:00:00.000000000'
#  '2013-05-20T00:00:00.000000000' '2012-02-06T00:00:00.000000000']
#
#
# Unique Values for column  Ship Date  are:
# ['2014-11-13T00:00:00.000000000' '2014-02-07T00:00:00.000000000'
#  '2014-10-18T00:00:00.000000000' ... '2013-04-08T00:00:00.000000000'
#  '2013-02-26T00:00:00.000000000' '2012-05-15T00:00:00.000000000']
#
#
# Unique Values for column  Ship Mode  are:
# ['First Class' 'Second Class' 'Same Day' 'Standard Class']
#
#
# Unique Values for column  Customer ID  are:
# ['AB-100151402' 'JR-162107' 'CR-127307' ... 'ZD-219251402' 'AS-285147'
#  'MC-1810093']
#
#
# Unique Values for column  Customer Name  are:
# ['Aaron Bergman' 'Justin Ritter' 'Craig Reiter' 'Katherine Murray'
#  'Rick Hansen' 'Jim Mitchum' 'Toby Swindell' 'Mick Brown' 'Anthony Jacobs'
# ...

# %% [markdown]
# Value Count of Each Categorical Column:

# %%
for i in non_num_df.columns:
    print("Value Count for column ",i," is:")
    Val_Counts = df[i].value_counts()
    print(Val_Counts)
    print()
    print()
# Out:
# Value Count for column  Order Date  is:
# 2015-06-18    135
# 2015-11-18    127
# 2015-09-03    126
# 2015-11-20    118
# 2015-12-29    116
#              ...
# 2014-03-17      1
# 2012-04-23      1
# 2013-09-23      1
# 2015-02-09      1
# 2012-02-06      1
# Name: Order Date, Length: 1430, dtype: int64
#
#
# Value Count for column  Ship Date  is:
# 2015-11-22    130
# 2015-09-07    115
# 2015-11-17    101
# 2015-12-07    101
# 2015-11-29    100
#              ...
# 2012-04-13      3
# 2014-03-21      3
# 2012-01-05      2
# 2012-01-06      2
# 2012-01-03      2
# Name: Ship Date, Length: 1464, dtype: int64
#
#
# Value Count for column  Ship Mode  is:
# Standard Class    30775
# Second Class      10309
# First Class        7505
# Same Day           2701
# Name: Ship Mode, dtype: int64
#
#
# Value Count for column  Customer ID  is:
# SV-203651406    26
# WB-218501404    24
# AP-109151404    23
# EM-1396082      21
# CS-121757       20
#                 ..
# LW-7215110       1
# ...

# %% [markdown]
# Percentage wise Analysis of Each categorical Column:

# %%
for i in non_num_df.columns:
    if len(non_num_df[i].value_counts().keys()) < 20:
        y = non_num_df[i].value_counts().values
        mylabels = non_num_df[i].value_counts().keys()
        
        plt.pie(y, labels = mylabels,autopct='%.2f')
        plt.title(i)
        plt.show()

# %% [markdown]
# Plotting Barplots for each categorical column using value Counts:

# %%
for i in non_num_df.columns:
    if len(non_num_df[i].value_counts().keys()) < 20:
        Val_Counts = df[i].value_counts()
        sns.barplot(Val_Counts.index , Val_Counts.values)
        plt.xticks(rotation=90)
        plt.xlabel(i)
        plt.ylabel('Count')
        plt.show()
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Owner\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Owner\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# ## Extra EDA:

# %%
df['Year'] = pd.DatetimeIndex(df['Order Date']).year
df.head(2)
# Out:
#   Order Date  Ship Date     Ship Mode   Customer ID  Customer Name    Segment  \
# 0 2014-11-11 2014-11-13   First Class  AB-100151402  Aaron Bergman   Consumer
# 1 2014-02-05 2014-02-07  Second Class     JR-162107  Justin Ritter  Corporate
#
#             City            State        Country      Region  ...    Category  \
# 0  Oklahoma City         Oklahoma  United States  Central US  ...  Technology
# 1     Wollongong  New South Wales      Australia     Oceania  ...   Furniture
#
#   Sub-Category                               Product Name     Sales Quantity  \
# 0       Phones                           Samsung Convoy 3   221.980        2
# 1       Chairs  Novimex Executive Leather Armchair, Black  3709.395        9
#
#    Discount    Profit  Shipping Cost  Order Priority  Year
# 0       0.0   62.1544          40.77            High  2014
# 1       0.1 -288.7650         923.63        Critical  2014
#
# [2 rows x 22 columns]

# %%
df['Month'] = pd.DatetimeIndex(df['Order Date']).month
df.head(2)
# Out:
#   Order Date  Ship Date     Ship Mode   Customer ID  Customer Name    Segment  \
# 0 2014-11-11 2014-11-13   First Class  AB-100151402  Aaron Bergman   Consumer
# 1 2014-02-05 2014-02-07  Second Class     JR-162107  Justin Ritter  Corporate
#
#             City            State        Country      Region  ...  \
# 0  Oklahoma City         Oklahoma  United States  Central US  ...
# 1     Wollongong  New South Wales      Australia     Oceania  ...
#
#   Sub-Category                               Product Name     Sales Quantity  \
# 0       Phones                           Samsung Convoy 3   221.980        2
# 1       Chairs  Novimex Executive Leather Armchair, Black  3709.395        9
#
#   Discount    Profit  Shipping Cost  Order Priority  Year  Month
# 0      0.0   62.1544          40.77            High  2014     11
# 1      0.1 -288.7650         923.63        Critical  2014      2
#
# [2 rows x 23 columns]

# %%
year1 = df['Year'].value_counts()
year1
# Out:
# 2015    17531
# 2014    13799
# 2013    10962
# 2012     8998
# Name: Year, dtype: int64

# %%
plt.figure(figsize = (16,5))
sns.barplot(year1.index, year1.values)
plt.show()
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Monthly Sale

# %%
m2 = df.groupby("Month").count()
m2
# Out:
#        Order Date  Ship Date  Ship Mode  Customer ID  Customer Name  Segment  \
# Month
# 1            2611       2611       2611         2611           2611     2611
# 2            2209       2209       2209         2209           2209     2209
# 3            3007       3007       3007         3007           3007     3007
# 4            3032       3032       3032         3032           3032     3032
# 5            3787       3787       3787         3787           3787     3787
# 6            5302       5302       5302         5302           5302     5302
# 7            3195       3195       3195         3195           3195     3195
# 8            5065       5065       5065         5065           5065     5065
# 9            5958       5958       5958         5958           5958     5958
# 10           4556       4556       4556         4556           4556     4556
# 11           6311       6311       6311         6311           6311     6311
# ...

# %%
plt.bar(m2.index , m2.Sales)
plt.show()

# %% [markdown]
# Yearly Sale

# %%
d2=df.groupby('Year')['Sales'].sum().sort_values(ascending=False)
d2
# Out:
# Year
# 2015    4.299866e+06
# 2014    3.405746e+06
# 2013    2.677439e+06
# 2012    2.259451e+06
# Name: Sales, dtype: float64

# %% [markdown]
# Bar Plot

# %%
plt.style.use("default")
plt.figure(figsize=(5,5))
sns.barplot(x="Order Priority", y="Sales", data=df[0:50])
plt.title("Order Priority vs Sales",fontsize=15)
plt.xlabel("Order Priority")
plt.ylabel("Sales")
plt.show()

# %%
op = df.groupby('Order Priority').count()
op
# Out:
#                 Order Date  Ship Date  Ship Mode  Customer ID  Customer Name  \
# Order Priority
# Critical              3932       3932       3932         3932           3932
# High                 15501      15501      15501        15501          15501
# Low                   2424       2424       2424         2424           2424
# Medium               29433      29433      29433        29433          29433
#
#                 Segment   City  State  Country  Region  ...  Category  \
# Order Priority                                          ...
# Critical           3932   3932   3932     3932    3932  ...      3932
# High              15501  15501  15501    15501   15501  ...     15501
# Low                2424   2424   2424     2424    2424  ...      2424
# Medium            29433  29433  29433    29433   29433  ...     29433
#
#                 Sub-Category  Product Name  Sales  Quantity  Discount  Profit  \
# Order Priority
# ...

# %%
plt.style.use("default")
plt.figure(figsize=(5,5))
sns.barplot(x="Category", y="Sales", data=df[0:50])
plt.title("Order Priority vs Sales",fontsize=15)
plt.xlabel("Order Priority")
plt.ylabel("Sales")
plt.show()

# %%
plt.figure(figsize=(12,6),dpi=100)
sns.barplot(x='Quantity',y='Sales',data=df,color='green')
plt.xlabel('Quantity')
plt.ylabel(' Sale')
plt.title('Quantity v  Sale',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(12,6),dpi=100)
sns.barplot(x='Category',y='Sales',data=df)

plt.show()

# %%
df.hist(figsize=(20,14))
plt.show()

# %%
df.corr()
# Out:
#                   Sales  Quantity  Discount    Profit  Shipping Cost  \
# Sales          1.000000  0.313577 -0.086722  0.484918       0.767835
# Quantity       0.313577  1.000000 -0.019875  0.104365       0.271804
# Discount      -0.086722 -0.019875  1.000000 -0.316490      -0.078153
# Profit         0.484918  0.104365 -0.316490  1.000000       0.354423
# Shipping Cost  0.767835  0.271804 -0.078153  0.354423       1.000000
# Year          -0.002905 -0.005049 -0.005894  0.002626      -0.003135
# Month          0.001851  0.020646 -0.000180  0.000173       0.004956
#
#                    Year     Month
# Sales         -0.002905  0.001851
# Quantity      -0.005049  0.020646
# Discount      -0.005894 -0.000180
# Profit         0.002626  0.000173
# Shipping Cost -0.003135  0.004956
# Year           1.000000 -0.011016
# Month         -0.011016  1.000000

# %%
plt.figure(figsize = (12,10))

sns.heatmap(df.corr(), annot =True)
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#               Sales      Quantity      Discount        Profit  Shipping Cost  \
# count  51290.000000  51290.000000  51290.000000  51290.000000   51290.000000
# mean     246.490581      3.476545      0.142908     28.610982      26.478567
# std      487.565361      2.278766      0.212280    174.340972      57.251373
# min        0.444000      1.000000      0.000000  -6599.978000       1.002000
# 25%       30.758625      2.000000      0.000000      0.000000       2.610000
# 50%       85.053000      3.000000      0.000000      9.240000       7.790000
# 75%      251.053200      5.000000      0.200000     36.810000      24.450000
# max    22638.480000     14.000000      0.850000   8399.976000     933.570000
#
#                Year         Month
# count  51290.000000  51290.000000
# mean    2013.777208      7.516027
# std        1.098931      3.300526
# min     2012.000000      1.000000
# 25%     2013.000000      5.000000
# 50%     2014.000000      8.000000
# ...

# %%
sns.boxplot(x='Quantity',data=df)
plt.show()
sns.boxplot(x='Sales',data=df)
plt.show()
sns.boxplot(x='Shipping Cost',data=df)
plt.show()
sns.boxplot(x='Discount',data=df)
plt.show()

# %% [markdown]
# PAIRPLOT
#
# A pairplot plot a pairwise relationships in a dataset. The pairplot function creates a grid of Axes such that each variable in data will by shared in the y-axis across a single row and in the x-axis across a single column.
#
# sns.pairplot(data=data)
# sns.pairplot(data=data)

# %%
sns.pairplot(data=df)
